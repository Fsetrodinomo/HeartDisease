# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dataset = pd.read_csv('/Users/fauve/Downloads/heart.csv')

# %%
print (dataset)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
dataset=dataset.dropna()
dataset=dataset [dataset.sex==1]
dataset=dataset [dataset.target==0]
dataset=dataset[dataset.age < 40]
dataset.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 212   39    1   0       118   219    0        1      140      0      1.2
# 227   35    1   0       120   198    0        1      130      1      1.6
# 239   35    1   0       126   282    0        0      156      1      0.0
# 259   38    1   3       120   231    0        1      182      1      3.8
#
#      slope  ca  thal  target
# 212      1   0     3       0
# 227      1   0     3       0
# 239      2   0     3       0
# 259      1   0     3       0

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True, linewidth=(0,5))

# %%
countNoDisease = len(df[df.target == 0])
countHaveDisease = len(df[df.target == 1])
print("Percentage of Patients Haven't Heart Disease: {:.2f}%".format((countNoDisease / (len(df.target))*100)))
print("Percentage of Patients Have Heart Disease: {:.2f}%".format((countHaveDisease / (len(df.target))*100)))
# Out:
# Percentage of Patients Haven't Heart Disease: 45.54%
# Percentage of Patients Have Heart Disease: 54.46%

# %%
sns.set(rc={'figure.figsize':(20,8.27)})
sns.countplot(x="chol", data=df, palette="bwr")
plt.show()

# %%
sns.countplot(x="cp", data=df, palette="bwr")
plt.show()

# %%
sns.set(rc={'figure.figsize':(20,8)})
sns.countplot(x="trestbps", data=df, palette="bwr", )
plt.show()

# %%
sns.countplot(x="fbs", data=df, palette="bwr")

# %%
sns.countplot(x="restecg", data=df, palette="bwr")

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x="oldpeak", data=df, palette="bwr")

# %%
sns.countplot(x="slope", data=df, palette="bwr")

# %%
sns.countplot(x="ca", data=df, palette="bwr")

# %%
sns.countplot(x="thal", data=df, palette="bwr")

# %%
sns.countplot(x="target", data=df, palette="bwr")

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x="age", data=df, palette="bwr")

# %%
sns.countplot(x="sex", data=df, palette="bwr")

# %%
 g = (sns.jointplot("age", "chol",
                   data=dataset, color="k")
     .plot_joint(sns.kdeplot, zorder=0, n_levels=6))

# %%
g = sns.jointplot("trestbps", "chol", data=dataset, kind="reg")

# %%
g = sns.jointplot("thalach", "cp", data=dataset, kind="reg")

# %%
g = sns.jointplot("age", "thalach", data=dataset, kind="reg")

# %%
 g = (sns.jointplot("age", "cp",
                   data=dataset, color="k")
     .plot_joint(sns.kdeplot, zorder=0, n_levels=6))

# %%
 g = (sns.jointplot("chol", "trestbps",
                   data=dataset, color="k")
     .plot_joint(sns.kdeplot, zorder=0, n_levels=6))

# %%
 g = (sns.jointplot("age", "chol",
                   data=dataset, color="k")
     .plot_joint(sns.kdeplot, zorder=0, n_levels=6))

# %%
x, y = np.random.randn(2, 3)
g = (sns.jointplot(x, y, kind="reg")
         .set_axis_labels("sex", "cp"))

# %%
g = sns.jointplot("chol", "age", data=dataset,
                   kind="kde", space=0, color="g")

# %%
g = sns.jointplot("thalach", "restecg", data=dataset,
                   kind="kde", space=0, color="g")

# %%
g = sns.jointplot("age", "oldpeak", data=dataset,
                   kind="kde", space=0, color="g")

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.601449  0.826087  0.478261  134.398551  251.086957  0.159420
# 1       52.496970  0.563636  1.375758  129.303030  242.230303  0.139394
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.449275  139.101449  0.550725  1.585507  1.166667  1.166667  2.543478
# 1       0.593939  158.466667  0.139394  0.583030  1.593939  0.363636  2.121212

# %%
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], c="red")
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)])
plt.legend(["Male", "Female"])
plt.xlabel("Disease")
plt.ylabel("Not disease")
plt.show()

# %%
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], c="red")
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)])
plt.legend(["Male", "Female"])
plt.xlabel("oldpeak")
plt.ylabel("Not disease")
plt.show()

# %%
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], c="red")
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)])
plt.legend(["Male", "Female"])
plt.xlabel("age")
plt.ylabel("oldpeak")
plt.show()

# %%
dataset = sns.load_dataset
dataset = dataset.pivot("chol", "age", "sex")
ax = sns.heatmap(dataset)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-240-86aca8d727fa> in <module>
#       1 dataset = sns.load_dataset
# ----> 2 dataset = dataset.pivot("chol", "age", "sex")
#       3 ax = sns.heatmap(dataset)
#
# AttributeError: 'function' object has no attribute 'pivot'
